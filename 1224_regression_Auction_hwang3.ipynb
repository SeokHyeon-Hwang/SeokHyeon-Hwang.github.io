# %%
import pandas as pd

# %%
train = pd.read_csv("Auction_master_train.csv")
test = pd.read_csv("Auction_master_test.csv")
print(train.shape, test.shape)
# Out:
# (1933, 41) (829, 41)

# %%
#!apt-get update -qq
#!apt-get install fonts-nanum* -qq

# %%
import matplotlib.font_manager as fm  # 폰트 관련 용도
import matplotlib.pyplot as plt
path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()
plt.title("복수의 plot 명령을 한 그림에서 표현")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-0e392efb43e8> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
# ----> 4 font_name = fm.FontProperties(fname=path, size=10).get_name()
#       5 print(font_name)
#       6 plt.rc('font', family=font_name)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py in get_name(self)
#     735         properties.
#     736         """
# --> 737         return get_font(findfont(self)).family_name
#     738
#     739     def get_style(self):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'

# %%
plt.title("복수의 plot 명령을 한 그림에서 표현",fontproperties=fontprop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-271787fdac3a> in <module>()
# ----> 1 plt.title("복수의 plot 명령을 한 그림에서 표현",fontproperties=fontprop)
#
# NameError: name 'fontprop' is not defined

# %%
train.head()
# Out:
#    Auction_key Auction_class Bid_class  Claim_price Appraisal_company  \
# 0         2687            임의        개별   1766037301              정명감정
# 1         2577            임의        일반    152946867               희감정
# 2         2197            임의        개별     11326510              혜림감정
# 3         2642            임의        일반    183581724              신라감정
# 4         1958            강제        일반     45887671              나라감정
#
#         Appraisal_date  Auction_count  Auction_miscarriage_count  \
# 0  2017-07-26 00:00:00              2                          1
# 1  2016-09-12 00:00:00              2                          1
# 2  2016-11-22 00:00:00              3                          2
# 3  2016-12-13 00:00:00              2                          1
# 4  2016-03-07 00:00:00              2                          1
#
#    Total_land_gross_area  Total_land_real_area     ...       Specific  \
# 0                12592.0                 37.35     ...            NaN
# 1                42478.1                 18.76     ...            NaN
# 2               149683.1                 71.00     ...            NaN
# 3                24405.0                 32.98     ...            NaN
# 4                  774.0                 45.18     ...            NaN
#
#    Share_auction_YorN   road_name  road_bunji1  road_bunji2  \
# 0                   N      해운대해변로         30.0          NaN
# 1                   N      마린시티2로         33.0          NaN
# 2                   N    모라로110번길         88.0          NaN
# 3                   N  황령대로319번가길        110.0          NaN
# 4                   N         오작로         51.0          NaN
#
#             Close_date Close_result    point.y     point.x Hammer_price
# 0  2018-06-14 00:00:00           배당  35.162717  129.137048    760000000
# 1  2017-03-30 00:00:00           배당  35.156633  129.145068    971889999
# 2  2017-12-13 00:00:00           배당  35.184601  128.996765     93399999
# 3  2017-12-27 00:00:00           배당  35.154180  129.089081    256899000
# 4  2016-10-04 00:00:00           배당  35.099630  128.998874    158660000
#
# [5 rows x 41 columns]

# %% [markdown]
# ##  EDA

# %%
train.hist(figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f73e2175b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e2195128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e21326a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e20e0cc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f73e20a2320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e20a2358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e2085a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e2045550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f73e20030f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e205b160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1f6a390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1f1cb00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1f3b860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1f15710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1ec4860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1e79ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1e3c550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1df0b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1da0d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f73e1d60400>]],
#       dtype=object)

# %%
test.hist(figsize=(15,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b112f9be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b11271c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b11226fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b111e6630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b1119ec50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b1119ec88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b11181f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b1113e5c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b110f2cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b110b1320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b11060630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b11014d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b10fd3390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b11004a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b10fb0550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b10f69b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b10f286a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b10edad30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b10e9b2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b10ebce80>]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,10))
sns.heatmap(train.corr(), annot=True, cmap='cubehelix_r'  )
plt.show()

# %% [markdown]
# ### 이상치 제거

# %%
train.columns
# Out:
# Index(['Auction_key', 'Auction_class', 'Bid_class', 'Claim_price',
#        'Appraisal_company', 'Appraisal_date', 'Auction_count',
#        'Auction_miscarriage_count', 'Total_land_gross_area',
#        'Total_land_real_area', 'Total_land_auction_area',
#        'Total_building_area', 'Total_building_auction_area',
#        'Total_appraisal_price', 'Minimum_sales_price', 'First_auction_date',
#        'Final_auction_date', 'Final_result', 'Creditor', 'addr_do', 'addr_si',
#        'addr_dong', 'addr_li', 'addr_san', 'addr_bunji1', 'addr_bunji2',
#        'addr_etc', 'Apartment_usage', 'Preserve_regist_date', 'Total_floor',
#        'Current_floor', 'Specific', 'Share_auction_YorN', 'road_name',
#        'road_bunji1', 'road_bunji2', 'Close_date', 'Close_result', 'point.y',
#        'point.x', 'Hammer_price'],
#       dtype='object')

# %%
plt.figure(figsize=(15,10))
plt.subplot(3,2,1)
train['Total_land_real_area'].hist()
plt.subplot(3,2,2)
train['Total_land_auction_area'].hist()
plt.subplot(3,2,3)
train['Total_building_area'].hist()
plt.subplot(3,2,4)
train['Total_building_auction_area'].hist()
plt.subplot(3,2,5)
train['Total_appraisal_price'].hist()
plt.subplot(3,2,6)
train['Minimum_sales_price'].hist()
plt.show()

# %%
dat = train['Bid_class']
dat.value_counts()
# Out:
# 일반    1796
# 개별     125
# 일괄      12
# Name: Bid_class, dtype: int64

# %%
train_sub = train[train.Total_land_auction_area <500]

# %%
plt.figure(figsize=(15,10))
plt.subplot(1,2,1)
ax= sns.boxplot(x="Bid_class", y="Total_land_auction_area", data=train_sub)
ax= sns.stripplot(x="Bid_class", y="Total_land_auction_area", data=train_sub, jitter=True, edgecolor="gray")
plt.subplot(1,2,2)
ax= sns.boxplot(x="Bid_class", y="Total_land_auction_area", data=test)
ax= sns.stripplot(x="Bid_class", y="Total_land_auction_area", data=test, jitter=True, edgecolor="gray")
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
train_sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1931 entries, 0 to 1932
# Data columns (total 41 columns):
# Auction_key                    1931 non-null int64
# Auction_class                  1931 non-null object
# Bid_class                      1931 non-null object
# Claim_price                    1931 non-null int64
# Appraisal_company              1931 non-null object
# Appraisal_date                 1931 non-null object
# Auction_count                  1931 non-null int64
# Auction_miscarriage_count      1931 non-null int64
# Total_land_gross_area          1931 non-null float64
# Total_land_real_area           1931 non-null float64
# Total_land_auction_area        1931 non-null float64
# Total_building_area            1931 non-null float64
# Total_building_auction_area    1931 non-null float64
# Total_appraisal_price          1931 non-null int64
# Minimum_sales_price            1931 non-null int64
# First_auction_date             1931 non-null object
# Final_auction_date             1931 non-null object
# Final_result                   1931 non-null object
# Creditor                       1931 non-null object
# addr_do                        1931 non-null object
# addr_si                        1931 non-null object
# addr_dong                      1931 non-null object
# addr_li                        23 non-null object
# addr_san                       1931 non-null object
# addr_bunji1                    1927 non-null float64
# addr_bunji2                    887 non-null float64
# addr_etc                       1931 non-null object
# Apartment_usage                1931 non-null object
# Preserve_regist_date           1931 non-null object
# Total_floor                    1931 non-null int64
# Current_floor                  1931 non-null int64
# Specific                       62 non-null object
# Share_auction_YorN             1931 non-null object
# road_name                      1931 non-null object
# road_bunji1                    1908 non-null float64
# road_bunji2                    155 non-null float64
# Close_date                     1931 non-null object
# Close_result                   1931 non-null object
# point.y                        1931 non-null float64
# point.x                        1931 non-null float64
# Hammer_price                   1931 non-null int64
# dtypes: float64(11), int64(9), object(21)
# memory usage: 713.6+ KB

# %% [markdown]
# ## 데이터 전처리

# %%
train_sub.columns
# Out:
# Index(['Auction_key', 'Auction_class', 'Bid_class', 'Claim_price',
#        'Appraisal_company', 'Appraisal_date', 'Auction_count',
#        'Auction_miscarriage_count', 'Total_land_gross_area',
#        'Total_land_real_area', 'Total_land_auction_area',
#        'Total_building_area', 'Total_building_auction_area',
#        'Total_appraisal_price', 'Minimum_sales_price', 'First_auction_date',
#        'Final_auction_date', 'Final_result', 'Creditor', 'addr_do', 'addr_si',
#        'addr_dong', 'addr_li', 'addr_san', 'addr_bunji1', 'addr_bunji2',
#        'addr_etc', 'Apartment_usage', 'Preserve_regist_date', 'Total_floor',
#        'Current_floor', 'Specific', 'Share_auction_YorN', 'road_name',
#        'road_bunji1', 'road_bunji2', 'Close_date', 'Close_result', 'point.y',
#        'point.x', 'Hammer_price'],
#       dtype='object')

# %%
print(train_sub.Auction_class.unique() )
print(train_sub.Bid_class.unique() )
print(train_sub.Auction_miscarriage_count.unique() )
print(train_sub.Final_result.unique() )
print(train_sub.Creditor.unique() )
print(train_sub.addr_do.unique() )
print(train_sub.addr_si.unique() )
print(train_sub.addr_dong.unique() )
print(train_sub.road_name.unique() )
print(train_sub.addr_etc.unique() )
# Out:
# ['임의' '강제']
# ['개별' '일반' '일괄']
# [1 2 0 5 4 6 3 7 9]
# ['낙찰']
# ['베리타스자산관리대부' '흥국저축은행' '국민은행' '고려저축은행' 'Private' '서울보증보험' '천마(새)' '대형선망수협'
#  '디에이치대부' '코카콜라음료' '한화저축은행' '프라임대부' '대부F&D' 'HK저축은행' '부산은행' '농협은행'
#  '청룡동(새)' '케이에이제7차유동화전문' '신용보증기금' '반야월농협' '제이티캐피탈' '오케이캐피탈대부' '우리은행'
#  '대구은행' '삼성카드' '영진건설' '한화손해보험' '하나은행' '유진대부금융' '동부화재해상보험' '비에스금융대부'
#  '(주)티베이' '범일5동(새)' '기술보증기금' '중소기업은행' '신한카드' '해운대신협' '승학(새)' '승학신협' '두산건설'
#  '동래농협' '농협생명보험' '한국주택금융공사' '현대캐피탈' 'NH농협캐피탈' '신한생명보험' '동부산농협' '경북대구낙농협'
#  '부영벽산아파트입주자대표회의' '한국씨티은행' 'KB국민카드' '디지비캐피탈' '베스트피플대부' '세종상호저축은행' '경남은행'
#  '북부산(새)' '한국무역보험공사' '스카이저축은행' '에이치에스제일차유동화전문' '영우유통' '명륜동(새)' '구서2동(새)'
#  '남천천신협' '부곡동(새)' '한화생명보험' '영남자원' '비엔케이캐피탈' '대양석유(주)' '부산주례(새)' '대청(새)'
#  '중부(새)' '기술신용보증기금' '범일동(새)' '경산농협' '국제저축은행' '그랜드코리아레저' '부산동부신협' '신한은행'
#  '웰릭스에프앤아이대부' '대구태영신협' '부산평화(새)' '진주서부농협' '감천1동(새)' '제1,2구잠수기수협' '농소농협'
#  'SC은행' '진해수협' '서1동(새)' '현대모비스' '부산화명(새)' '성가신협' '제네시스유동화전문' '아주캐피탈'
#  '광안신협' '시민공원(새)' 'JT캐피탈' '북부산신협' '사직1동(새)' '신괴정(새)' '진주저축은행' '감만동(새)'
#  '중앙농협' '페퍼저축은행' '늘푸른사상(새)' '금호상사' '새남해(새)' '대부에프앤디' 'KB캐피탈' '서부(새)'
#  '한국투자저축은행' '삼성화재해상보험' '예가람저축은행' '우리카드' '마산수협' '산청군농협' '진량농협' '희망모아유동화전문'
#  '케이미트부산' '괴정3동(새)' '경상소방설비' '피티코엑심만디리파이낸스' '중림전기물류' '(주)삼진' '부산원광신협'
#  '(주)디케이씨' '괴정4동(새)' '(주)연미' 'KB손해보험' '태종대신협' '제이자산관리' '근로복지공단' '해운대중앙(새)'
#  '부산시수협' '하나저축은행' '남부중앙(새)' '현대라이프생명보험' '세일피에스' '우리인베스트대부' '대경철강' '효성캐피탈'
#  '상록수제일차유동화전문' '재송동(새)' '금융단지(새)' '경산제지' '농협경제지주' '현대건설외1' '장산(새)'
#  '대신저축은행' '(주)한일식품외1' '가락농협' '솔브레인저축은행' '초량4동(새)' '에스케이건설' '마산시농협'
#  '전포2동(새)' '금정기업(주)' '전문건설공제조합' '신용보증재단' '부산성의신협' 'SK건설' '주택도시보증공사' '유원상사'
#  '의령농협' '용당동(새)' '수정5동(새)' '찬호론대부' '한국외환은행' 'IBK캐피탈' '롯데카드' '진주동부농협'
#  '케이알앤씨' '신만덕(새)' '경상남도정치망수협' '북부산농협' '엠메이드대부' '부산신용보증재단' '수영중앙(새)'
#  '서대구신협' '에이스저축은행' '제이티친애저축은행' '(주)코엔지' '현대해상화재보험' '삼성생명보험' '송도신협' '서동(새)'
#  '우리저축은행' '페르노리카코리아임페리얼' '광남(새)' '부산장우신협' '우리이에이제12차유동화전문' '흥국생명보험'
#  '로얄앤컴퍼니' '하나캐피탈' '한국양계축협' '한국군사문제연구원' '에어플러스' '민락동(새)' '중구중앙(새)' '수협은행'
#  '(주)동양' 'SC캐피탈' '한국자산관리공사' '비전에이치' '에프케이엔1612유동화전문' '제일종합주류판매상사' '피앤에프'
#  '광안(새)' '반여2,3동(새)' 'BMW파이낸셜서비스코리아' '문현4동(새)' '(주)발해하우징' '부산2저축은행'
#  '상록수제1차유동화전문' '크레텍책임' '영남저축은행' '당감신협' '무림캐피탈' '솔로몬저축은행' '전북은행' '위니더스'
#  '광주농협' '성남중앙신협' '관악농협' '케이에이치에너지' '북서울농협' '투에스캐피탈대부' '코리안리재보험'
#  '아현제3구역주택재개발정비사업조합' '기산메디칼' '수협중앙' '경산신협' '구미상호저축은행' '영등포농협' '교보생명보험'
#  '(주)빌트원' '오에스비저축은행' '홍콩상하이은행' '농협자산관리' '현대저축은행' '삼호저축은행' '성일건설'
#  '장안시영2단지2차주택재건축정비사업조합' '홍제(새)' '대한주택보증' '오케이저축은행' '(주)북센' '코리아카고피아'
#  '서광주농협' '유니온저축은행' '지성파이낸스대부' '한주저축은행' '운봉(새)' '동양저축은행' 'SBI저축은행' '모아저축은행'
#  '광등종합건설' '청주(새)' '건우철강' '(주)선진' '아라에이엠씨대부' '유아이제14차유동화전문' '세아네트웍스'
#  '유원자산관리대부' '한국자산관리' '이씨에이시스템' '흥국화재해상보험' '인도해외은행' '우리기술' '(주)큐브스'
#  '(주)KCC' '신길6동(새)' '서서울농협' '쥴릭파마코리아' '신길중앙(새)' '이토플러스' '서천신협' '제이캐피탈대부'
#  '강서농협' '에스비아이저축은행' '서울구로구' 'LS엠트론' '광주은행' '조은저축은행' '안양남부(새)' 'NH저축은행'
#  '서울원예농협' '한국산업은행' '부산저축은행' 'JM인베스트먼트' '드림상호저축은행' '인천중부신협' '베리타스에프앤아이'
#  '(주)찬호론대부' '선호상사' '예스캐피탈대부' '푸른이상호저축' '한빛자산관리대부' '하남농협' '엘케이에이엠씨'
#  'OSB저축은행' '캐쉬카우대부' '동양생명보험' '종로동부(새)' '대화주류' '대동캐피탈대부' '해방새대부'
#  '케이아이코아즈대부' '환영철강공업' 'HJ인베스트먼트AMC대부' '은평중앙신협' '우영파이낸셜대부' '아현제3구역주택재개발'
#  '대백저축은행' '로버스타' '금화상호저축은행' '한마음금융' '유니온상호저축은행' '삼정씨에프엔' '광명농협' '노블홀딩스대부'
#  '프라임상호저축은행' '청도기공' '위드에셋자산관리대부' '경기신용보증재단' '씨와이대부' 'J캐피탈대부' '1509유동화전문'
#  '종로기업' '남광제화' '서울시구로구' '한국가설산업' '에이피제3비유동화전문' '금화저축은행' '부명세원대부금융'
#  '푸른상호저축은행' '에이피제3에이유동화전문' 'KCC건설' '예천농협' '제자교회' '밀양박씨낙촌공파종친회' '일동후디스'
#  '국민건강보험공단' '경서농협' '동국제강' '채움산업개발' '상도제10구역주택재개발정비사업조합' '한평신협' '삼화상호저축은행'
#  '광명제일(새)' '기협기술금융대부' 'OK저축은행' '보해상호저축은행' '신림서부(새)' '근해안강망수협' '코오롱글로벌'
#  '성동(새)' '한국기업투자' '제이비우리캐피탈' '지인베스트대부' '서울축협' '동수원신협' '한국저축은행' '예스자산대부'
#  '벨류대부모기지' '영화아파트재건축조합' '동부제철' '원남토건' '쓰리아이전기' '한강대부' '군포(새)' '대진디엠피'
#  '아주저축은행' '유원대부' '안양저축은행' 'UD제사차유동화전문' '송인서적' '행복자산관리대부' '신정주류' '산림조합중앙회'
#  '우주아이엔씨' '종로광장(새)' '평택상호저축은행' '대성주류판매' '서대구농협' '보은자연농산' '운진강업' '청주저축은행'
#  '한국양토양록축협' '여수해양' '유에이치제5차유동화전문' '서울우유협동조합' '한국축산의희망서울사료' '아이비자산관리'
#  '캐논코리아비즈니스솔루션' '만수(새)' '북광주(새)' '청도일성(새)' '자미래저축은행' '(주)봉천' '웰컴저축은행'
#  '와이지에셋대부' '세도농협' '제3.4구잠수기수협' '광주스마일대부' '(주)알루코' '베리타스FNI' '정읍농협'
#  '(주)오티오대부' '성남제일(새)' '아세아캐피탈대부금융' '남동농협' '인텍앤컴퍼니' '서울시도시철도공사' '(주)필래'
#  '위즈씨앤에스' '수원(새)' '아현제3구역주택재개발정비' '와이더블유' '페페저축은행' '경기저축은행' '아림조명상사'
#  '오티오대부' '둔촌아파트입주자대표회의' '(주)대정실업' '우리에프앤아이제40차유동화전문' 'IBK저축은행' '인성저축은행'
#  '농협양곡' '미래저축은행' '신라외식개발' '인제학원' '원효중앙(새)' '하나카드' '동부라이텍' '지비자산관리'
#  '삼정상호저축은행' '회기휘경(새)' '강남영동(새)' '삼정에셋대부' '더케이저축은행' '동원건설산업' '국민행복기금'
#  '대한저축은행' '토마토2저축은행' '서울신용보증재단' '굿이에프대부' '히어로비케이대부']
# ['부산' '서울']
# ['해운대구' '사상구' '남구' '사하구' '영도구' '서구' '부산진구' '연제구' '수영구' '동래구' '동구' '중구'
#  '강서구' '북구' '금정구' '기장군' '강남구' '은평구' '서초구' '영등포구' '양천구' '마포구' '금천구' '성동구'
#  '노원구' '서대문구' '용산구' '구로구' '강북구' '관악구' '송파구' '도봉구' '광진구' '중랑구' '동대문구' '강동구'
#  '성북구' '동작구' '종로구']
# ['우동' '모라동' '대연동' '괴정동' '청학동' '동삼동' '용호동' '암남동' '재송동' '양정동' '신평동' '중동'
#  '연산동' '민락동' '온천동' '수정동' '봉래동4가' '부민동3가' '하단동' '영주동' '명지동' '낙민동' '금곡동'
#  '엄궁동' '범일동' '반여동' '화명동' '보수동2가' '거제동' '연지동' '주례동' '부곡동' '전포동' '당감동' '정관읍'
#  '장림동' '대교동1가' '덕포동' '구포동' '반송동' '토성동5가' '수영동' '학장동' '다대동' '가야동' '만덕동'
#  '문현동' '개금동' '당리동' '덕천동' '좌동' '부전동' '초량동' '일광면' '범천동' '구서동' '좌천동' '부암동'
#  '기장읍' '장전동' '용당동' '수안동' '감천동' '명륜동' '명장동' '광안동' '사직동' '남산동' '구평동' '망미동'
#  '남천동' '대청동4가' '감만동' '복천동' '보수동1가' '부평동2가' '장안읍' '지사동' '영선동3가' '서동'
#  '서대신동3가' '대평동1가' '범전동' '안락동' '초읍동' '괘법동' '서대신동2가' '남부민동' '부평동4가' '영선동4가'
#  '우암동' '감전동' '청담동' '역촌동' '서초동' '당산동' '진관동' '목동' '아현동' '시흥동' '신정동' '행당동'
#  '반포동' '하계동' '염창동' '홍제동' '한남동' '고척동' '번동' '봉천동' '화곡동' '잠실동' '월계동' '홍은동'
#  '논현동' '창동' '신림동' '광장동' '율현동' '신월동' '상계동' '구로동' '도봉동' '중계동' '방배동' '신내동'
#  '면목동' '도곡동' '장지동' '풍납동' '중화동' '공릉동' '도화동' '이문동' '용두동' '북가좌동' '개포동' '방학동'
#  '명일동' '영등포동8가' '성수동2가' '삼선동4가' '흑석동' '양평동6가' '현석동' '대흥동' '돈암동' '노량진동'
#  '신원동' '방이동' '회기동' '역삼동' '마장동' '사당동' '장안동' '잠원동' '개봉동' '대조동' '송파동' '정릉동'
#  '신대방동' '쌍문동' '미아동' '방화동' '응암동' '삼성동' '독산동' '오류동' '가락동' '하중동' '길음동' '천호동'
#  '압구정동' '구의동' '평창동' '길동' '둔촌동' '가양동' '남가좌동' '성산동' '신당동' '남현동' '고덕동' '여의도동'
#  '신도림동' '상도동' '답십리동' '마천동' '황학동' '연희동' '암사동' '이태원동' '신수동' '묵동' '휘경동'
#  '당산동4가' '자양동' '신사동' '신길동' '영등포동' '전농동' '대치동' '이촌동' '수색동' '창신동' '신천동'
#  '상일동' '수서동' '동작동' '군자동' '대림동' '서교동' '노고산동' '용답동' '망우동' '옥수동' '공덕동' '종암동'
#  '가산동' '내수동' '녹번동' '망원동' '연남동' '창전동' '온수동' '문래동3가' '수유동' '충정로3가' '인의동'
#  '등촌동' '본동' '한강로3가' '구산동' '오금동' '중림동' '홍익동' '문정동' '현저동' '불광동' '내발산동' '도원동'
#  '삼선동2가' '양재동' '무악동' '성수동1가' '거여동' '상봉동' '대방동' '응봉동' '일원동' '서빙고동' '우이동'
#  '세곡동' '청량리동' '하월곡동' '강일동' '내곡동' '양평동1가' '삼선동3가' '성내동' '회현동1가' '당주동' '효창동'
#  '마곡동' '안암동3가' '상수동' '상암동' '하왕십리동' '회현동2가' '우면동' '천왕동' '갈현동' '장위동' '양평동5가'
#  '문배동' '당산동1가' '청암동' '중곡동' '충무로4가' '보문동4가' '남대문로5가' '제기동' '원효로3가' '석관동'
#  '영등포동7가']
# ['해운대해변로' '마린시티2로' '모라로110번길' ... '덕릉로83길' '가마산로20다길' '덕릉로94길']
# ['해운대엑소디움 5층 101-502호' '해운대두산위브더제니스 103동 51층 5103호' '백양그린 206동 14층 1403호'
#  ... ',회현동2가 89 남산롯데캐슬아이리스 19층 102-1905호' '삼성래미안 110동 11층 1102호'
#  '강서한강자이 106동 7층 703호']

# %%
print(train_sub.Auction_class.unique() )
print(train_sub.Bid_class.unique() )
print(train_sub.Auction_miscarriage_count.unique() )
print(train_sub.Final_result.unique() )
print(train_sub.Creditor.unique() )
print(train_sub.addr_do.unique() )
print(train_sub.addr_si.unique() )
print(train_sub.addr_dong.unique() )
print(train_sub.road_name.unique() )
print(train_sub.addr_etc.unique() )
# Out:
# ['임의' '강제']
# ['개별' '일반' '일괄']
# [1 2 0 5 4 6 3 7 9]
# ['낙찰']
# ['베리타스자산관리대부' '흥국저축은행' '국민은행' '고려저축은행' 'Private' '서울보증보험' '천마(새)' '대형선망수협'
#  '디에이치대부' '코카콜라음료' '한화저축은행' '프라임대부' '대부F&D' 'HK저축은행' '부산은행' '농협은행'
#  '청룡동(새)' '케이에이제7차유동화전문' '신용보증기금' '반야월농협' '제이티캐피탈' '오케이캐피탈대부' '우리은행'
#  '대구은행' '삼성카드' '영진건설' '한화손해보험' '하나은행' '유진대부금융' '동부화재해상보험' '비에스금융대부'
#  '(주)티베이' '범일5동(새)' '기술보증기금' '중소기업은행' '신한카드' '해운대신협' '승학(새)' '승학신협' '두산건설'
#  '동래농협' '농협생명보험' '한국주택금융공사' '현대캐피탈' 'NH농협캐피탈' '신한생명보험' '동부산농협' '경북대구낙농협'
#  '부영벽산아파트입주자대표회의' '한국씨티은행' 'KB국민카드' '디지비캐피탈' '베스트피플대부' '세종상호저축은행' '경남은행'
#  '북부산(새)' '한국무역보험공사' '스카이저축은행' '에이치에스제일차유동화전문' '영우유통' '명륜동(새)' '구서2동(새)'
#  '남천천신협' '부곡동(새)' '한화생명보험' '영남자원' '비엔케이캐피탈' '대양석유(주)' '부산주례(새)' '대청(새)'
#  '중부(새)' '기술신용보증기금' '범일동(새)' '경산농협' '국제저축은행' '그랜드코리아레저' '부산동부신협' '신한은행'
#  '웰릭스에프앤아이대부' '대구태영신협' '부산평화(새)' '진주서부농협' '감천1동(새)' '제1,2구잠수기수협' '농소농협'
#  'SC은행' '진해수협' '서1동(새)' '현대모비스' '부산화명(새)' '성가신협' '제네시스유동화전문' '아주캐피탈'
#  '광안신협' '시민공원(새)' 'JT캐피탈' '북부산신협' '사직1동(새)' '신괴정(새)' '진주저축은행' '감만동(새)'
#  '중앙농협' '페퍼저축은행' '늘푸른사상(새)' '금호상사' '새남해(새)' '대부에프앤디' 'KB캐피탈' '서부(새)'
#  '한국투자저축은행' '삼성화재해상보험' '예가람저축은행' '우리카드' '마산수협' '산청군농협' '진량농협' '희망모아유동화전문'
#  '케이미트부산' '괴정3동(새)' '경상소방설비' '피티코엑심만디리파이낸스' '중림전기물류' '(주)삼진' '부산원광신협'
#  '(주)디케이씨' '괴정4동(새)' '(주)연미' 'KB손해보험' '태종대신협' '제이자산관리' '근로복지공단' '해운대중앙(새)'
#  '부산시수협' '하나저축은행' '남부중앙(새)' '현대라이프생명보험' '세일피에스' '우리인베스트대부' '대경철강' '효성캐피탈'
#  '상록수제일차유동화전문' '재송동(새)' '금융단지(새)' '경산제지' '농협경제지주' '현대건설외1' '장산(새)'
#  '대신저축은행' '(주)한일식품외1' '가락농협' '솔브레인저축은행' '초량4동(새)' '에스케이건설' '마산시농협'
#  '전포2동(새)' '금정기업(주)' '전문건설공제조합' '신용보증재단' '부산성의신협' 'SK건설' '주택도시보증공사' '유원상사'
#  '의령농협' '용당동(새)' '수정5동(새)' '찬호론대부' '한국외환은행' 'IBK캐피탈' '롯데카드' '진주동부농협'
#  '케이알앤씨' '신만덕(새)' '경상남도정치망수협' '북부산농협' '엠메이드대부' '부산신용보증재단' '수영중앙(새)'
#  '서대구신협' '에이스저축은행' '제이티친애저축은행' '(주)코엔지' '현대해상화재보험' '삼성생명보험' '송도신협' '서동(새)'
#  '우리저축은행' '페르노리카코리아임페리얼' '광남(새)' '부산장우신협' '우리이에이제12차유동화전문' '흥국생명보험'
#  '로얄앤컴퍼니' '하나캐피탈' '한국양계축협' '한국군사문제연구원' '에어플러스' '민락동(새)' '중구중앙(새)' '수협은행'
#  '(주)동양' 'SC캐피탈' '한국자산관리공사' '비전에이치' '에프케이엔1612유동화전문' '제일종합주류판매상사' '피앤에프'
#  '광안(새)' '반여2,3동(새)' 'BMW파이낸셜서비스코리아' '문현4동(새)' '(주)발해하우징' '부산2저축은행'
#  '상록수제1차유동화전문' '크레텍책임' '영남저축은행' '당감신협' '무림캐피탈' '솔로몬저축은행' '전북은행' '위니더스'
#  '광주농협' '성남중앙신협' '관악농협' '케이에이치에너지' '북서울농협' '투에스캐피탈대부' '코리안리재보험'
#  '아현제3구역주택재개발정비사업조합' '기산메디칼' '수협중앙' '경산신협' '구미상호저축은행' '영등포농협' '교보생명보험'
#  '(주)빌트원' '오에스비저축은행' '홍콩상하이은행' '농협자산관리' '현대저축은행' '삼호저축은행' '성일건설'
#  '장안시영2단지2차주택재건축정비사업조합' '홍제(새)' '대한주택보증' '오케이저축은행' '(주)북센' '코리아카고피아'
#  '서광주농협' '유니온저축은행' '지성파이낸스대부' '한주저축은행' '운봉(새)' '동양저축은행' 'SBI저축은행' '모아저축은행'
#  '광등종합건설' '청주(새)' '건우철강' '(주)선진' '아라에이엠씨대부' '유아이제14차유동화전문' '세아네트웍스'
#  '유원자산관리대부' '한국자산관리' '이씨에이시스템' '흥국화재해상보험' '인도해외은행' '우리기술' '(주)큐브스'
#  '(주)KCC' '신길6동(새)' '서서울농협' '쥴릭파마코리아' '신길중앙(새)' '이토플러스' '서천신협' '제이캐피탈대부'
#  '강서농협' '에스비아이저축은행' '서울구로구' 'LS엠트론' '광주은행' '조은저축은행' '안양남부(새)' 'NH저축은행'
#  '서울원예농협' '한국산업은행' '부산저축은행' 'JM인베스트먼트' '드림상호저축은행' '인천중부신협' '베리타스에프앤아이'
#  '(주)찬호론대부' '선호상사' '예스캐피탈대부' '푸른이상호저축' '한빛자산관리대부' '하남농협' '엘케이에이엠씨'
#  'OSB저축은행' '캐쉬카우대부' '동양생명보험' '종로동부(새)' '대화주류' '대동캐피탈대부' '해방새대부'
#  '케이아이코아즈대부' '환영철강공업' 'HJ인베스트먼트AMC대부' '은평중앙신협' '우영파이낸셜대부' '아현제3구역주택재개발'
#  '대백저축은행' '로버스타' '금화상호저축은행' '한마음금융' '유니온상호저축은행' '삼정씨에프엔' '광명농협' '노블홀딩스대부'
#  '프라임상호저축은행' '청도기공' '위드에셋자산관리대부' '경기신용보증재단' '씨와이대부' 'J캐피탈대부' '1509유동화전문'
#  '종로기업' '남광제화' '서울시구로구' '한국가설산업' '에이피제3비유동화전문' '금화저축은행' '부명세원대부금융'
#  '푸른상호저축은행' '에이피제3에이유동화전문' 'KCC건설' '예천농협' '제자교회' '밀양박씨낙촌공파종친회' '일동후디스'
#  '국민건강보험공단' '경서농협' '동국제강' '채움산업개발' '상도제10구역주택재개발정비사업조합' '한평신협' '삼화상호저축은행'
#  '광명제일(새)' '기협기술금융대부' 'OK저축은행' '보해상호저축은행' '신림서부(새)' '근해안강망수협' '코오롱글로벌'
#  '성동(새)' '한국기업투자' '제이비우리캐피탈' '지인베스트대부' '서울축협' '동수원신협' '한국저축은행' '예스자산대부'
#  '벨류대부모기지' '영화아파트재건축조합' '동부제철' '원남토건' '쓰리아이전기' '한강대부' '군포(새)' '대진디엠피'
#  '아주저축은행' '유원대부' '안양저축은행' 'UD제사차유동화전문' '송인서적' '행복자산관리대부' '신정주류' '산림조합중앙회'
#  '우주아이엔씨' '종로광장(새)' '평택상호저축은행' '대성주류판매' '서대구농협' '보은자연농산' '운진강업' '청주저축은행'
#  '한국양토양록축협' '여수해양' '유에이치제5차유동화전문' '서울우유협동조합' '한국축산의희망서울사료' '아이비자산관리'
#  '캐논코리아비즈니스솔루션' '만수(새)' '북광주(새)' '청도일성(새)' '자미래저축은행' '(주)봉천' '웰컴저축은행'
#  '와이지에셋대부' '세도농협' '제3.4구잠수기수협' '광주스마일대부' '(주)알루코' '베리타스FNI' '정읍농협'
#  '(주)오티오대부' '성남제일(새)' '아세아캐피탈대부금융' '남동농협' '인텍앤컴퍼니' '서울시도시철도공사' '(주)필래'
#  '위즈씨앤에스' '수원(새)' '아현제3구역주택재개발정비' '와이더블유' '페페저축은행' '경기저축은행' '아림조명상사'
#  '오티오대부' '둔촌아파트입주자대표회의' '(주)대정실업' '우리에프앤아이제40차유동화전문' 'IBK저축은행' '인성저축은행'
#  '농협양곡' '미래저축은행' '신라외식개발' '인제학원' '원효중앙(새)' '하나카드' '동부라이텍' '지비자산관리'
#  '삼정상호저축은행' '회기휘경(새)' '강남영동(새)' '삼정에셋대부' '더케이저축은행' '동원건설산업' '국민행복기금'
#  '대한저축은행' '토마토2저축은행' '서울신용보증재단' '굿이에프대부' '히어로비케이대부']
# ['부산' '서울']
# ['해운대구' '사상구' '남구' '사하구' '영도구' '서구' '부산진구' '연제구' '수영구' '동래구' '동구' '중구'
#  '강서구' '북구' '금정구' '기장군' '강남구' '은평구' '서초구' '영등포구' '양천구' '마포구' '금천구' '성동구'
#  '노원구' '서대문구' '용산구' '구로구' '강북구' '관악구' '송파구' '도봉구' '광진구' '중랑구' '동대문구' '강동구'
#  '성북구' '동작구' '종로구']
# ['우동' '모라동' '대연동' '괴정동' '청학동' '동삼동' '용호동' '암남동' '재송동' '양정동' '신평동' '중동'
#  '연산동' '민락동' '온천동' '수정동' '봉래동4가' '부민동3가' '하단동' '영주동' '명지동' '낙민동' '금곡동'
#  '엄궁동' '범일동' '반여동' '화명동' '보수동2가' '거제동' '연지동' '주례동' '부곡동' '전포동' '당감동' '정관읍'
#  '장림동' '대교동1가' '덕포동' '구포동' '반송동' '토성동5가' '수영동' '학장동' '다대동' '가야동' '만덕동'
#  '문현동' '개금동' '당리동' '덕천동' '좌동' '부전동' '초량동' '일광면' '범천동' '구서동' '좌천동' '부암동'
#  '기장읍' '장전동' '용당동' '수안동' '감천동' '명륜동' '명장동' '광안동' '사직동' '남산동' '구평동' '망미동'
#  '남천동' '대청동4가' '감만동' '복천동' '보수동1가' '부평동2가' '장안읍' '지사동' '영선동3가' '서동'
#  '서대신동3가' '대평동1가' '범전동' '안락동' '초읍동' '괘법동' '서대신동2가' '남부민동' '부평동4가' '영선동4가'
#  '우암동' '감전동' '청담동' '역촌동' '서초동' '당산동' '진관동' '목동' '아현동' '시흥동' '신정동' '행당동'
#  '반포동' '하계동' '염창동' '홍제동' '한남동' '고척동' '번동' '봉천동' '화곡동' '잠실동' '월계동' '홍은동'
#  '논현동' '창동' '신림동' '광장동' '율현동' '신월동' '상계동' '구로동' '도봉동' '중계동' '방배동' '신내동'
#  '면목동' '도곡동' '장지동' '풍납동' '중화동' '공릉동' '도화동' '이문동' '용두동' '북가좌동' '개포동' '방학동'
#  '명일동' '영등포동8가' '성수동2가' '삼선동4가' '흑석동' '양평동6가' '현석동' '대흥동' '돈암동' '노량진동'
#  '신원동' '방이동' '회기동' '역삼동' '마장동' '사당동' '장안동' '잠원동' '개봉동' '대조동' '송파동' '정릉동'
#  '신대방동' '쌍문동' '미아동' '방화동' '응암동' '삼성동' '독산동' '오류동' '가락동' '하중동' '길음동' '천호동'
#  '압구정동' '구의동' '평창동' '길동' '둔촌동' '가양동' '남가좌동' '성산동' '신당동' '남현동' '고덕동' '여의도동'
#  '신도림동' '상도동' '답십리동' '마천동' '황학동' '연희동' '암사동' '이태원동' '신수동' '묵동' '휘경동'
#  '당산동4가' '자양동' '신사동' '신길동' '영등포동' '전농동' '대치동' '이촌동' '수색동' '창신동' '신천동'
#  '상일동' '수서동' '동작동' '군자동' '대림동' '서교동' '노고산동' '용답동' '망우동' '옥수동' '공덕동' '종암동'
#  '가산동' '내수동' '녹번동' '망원동' '연남동' '창전동' '온수동' '문래동3가' '수유동' '충정로3가' '인의동'
#  '등촌동' '본동' '한강로3가' '구산동' '오금동' '중림동' '홍익동' '문정동' '현저동' '불광동' '내발산동' '도원동'
#  '삼선동2가' '양재동' '무악동' '성수동1가' '거여동' '상봉동' '대방동' '응봉동' '일원동' '서빙고동' '우이동'
#  '세곡동' '청량리동' '하월곡동' '강일동' '내곡동' '양평동1가' '삼선동3가' '성내동' '회현동1가' '당주동' '효창동'
#  '마곡동' '안암동3가' '상수동' '상암동' '하왕십리동' '회현동2가' '우면동' '천왕동' '갈현동' '장위동' '양평동5가'
#  '문배동' '당산동1가' '청암동' '중곡동' '충무로4가' '보문동4가' '남대문로5가' '제기동' '원효로3가' '석관동'
#  '영등포동7가']
# ['해운대해변로' '마린시티2로' '모라로110번길' ... '덕릉로83길' '가마산로20다길' '덕릉로94길']
# ['해운대엑소디움 5층 101-502호' '해운대두산위브더제니스 103동 51층 5103호' '백양그린 206동 14층 1403호'
#  ... ',회현동2가 89 남산롯데캐슬아이리스 19층 102-1905호' '삼성래미안 110동 11층 1102호'
#  '강서한강자이 106동 7층 703호']

# %%
print(train_sub.Auction_class.unique() )
print(train_sub.Bid_class.unique() )
print(train_sub.Final_result.unique() )
print(train_sub.Apartment_usage.unique() )
# Out:
# ['임의' '강제']
# ['개별' '일반' '일괄']
# ['낙찰']
# ['주상복합' '아파트']

# %%
train_sub['Auction_class_01'] = train_sub["Auction_class"] == "임의"
train_sub['Auction_class_02'] = train_sub["Auction_class"] == "강제"

train_sub['Bid_class_01'] = train_sub["Auction_class"] == "개별"
train_sub['Bid_class_02'] = train_sub["Auction_class"] == "일반"
train_sub['Bid_class_03'] = train_sub["Auction_class"] == "일괄"

train_sub['Apartment_usage_01'] = train_sub["Apartment_usage"] == "주상복합"
train_sub['Apartment_usage_02'] = train_sub["Apartment_usage"] == "아파트"
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
test_sub = test

test_sub['Apartment_usage_01'] = test_sub["Apartment_usage"] == "주상복합"
test_sub['Apartment_usage_02'] = test_sub["Apartment_usage"] == "아파트"
test_sub['Auction_class_01'] = test_sub["Auction_class"] == "임의"
test_sub['Auction_class_02'] = test_sub["Auction_class"] == "강제"
test_sub['Bid_class_01'] = test_sub["Auction_class"] == "개별"
test_sub['Bid_class_02'] = test_sub["Auction_class"] == "일반"
test_sub['Bid_class_03'] = test_sub["Auction_class"] == "일괄"

# %%
train_sub.columns
# Out:
# Index(['Auction_key', 'Auction_class', 'Bid_class', 'Claim_price',
#        'Appraisal_company', 'Appraisal_date', 'Auction_count',
#        'Auction_miscarriage_count', 'Total_land_gross_area',
#        'Total_land_real_area', 'Total_land_auction_area',
#        'Total_building_area', 'Total_building_auction_area',
#        'Total_appraisal_price', 'Minimum_sales_price', 'First_auction_date',
#        'Final_auction_date', 'Final_result', 'Creditor', 'addr_do', 'addr_si',
#        'addr_dong', 'addr_li', 'addr_san', 'addr_bunji1', 'addr_bunji2',
#        'addr_etc', 'Apartment_usage', 'Preserve_regist_date', 'Total_floor',
#        'Current_floor', 'Specific', 'Share_auction_YorN', 'road_name',
#        'road_bunji1', 'road_bunji2', 'Close_date', 'Close_result', 'point.y',
#        'point.x', 'Hammer_price', 'Auction_class_01', 'Auction_class_02',
#        'Bid_class_01', 'Bid_class_02', 'Bid_class_03', 'Apartment_usage_01',
#        'Apartment_usage_02'],
#       dtype='object')

# %%
sel = ['Claim_price',
       'Auction_count',
       'Auction_miscarriage_count', 'Total_land_gross_area',
       'Total_land_real_area', 'Total_land_auction_area',
       'Total_building_area', 'Total_building_auction_area',
       'Total_appraisal_price', 'Minimum_sales_price', 'Total_floor',
       'Current_floor', 'Hammer_price', 'Auction_class_01', 'Auction_class_02',
       'Bid_class_01', 'Bid_class_02', 'Bid_class_03', 'Apartment_usage_01',
       'Apartment_usage_02']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.linear_model import Ridge   # 릿지회귀

# %%
tr_sel = train_sub[sel]
test_sel =test_sub[sel]

# %%
X = train_sub[sel]
y = train_sub['Hammer_price']
testX = test_sub[sel]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
lr = LinearRegression().fit(X_train, y_train)
ridge01 = Ridge(alpha=10).fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.006374e-23
#   overwrite_a=True).T

# %%
print("훈련 세트 점수 : {:.2f}".format(lr.score(X_train, y_train)))
print("테스트 세트 점수 : {:.2f}".format(lr.score(X_test, y_test)))
print("훈련 세트 점수 : {:.2f}".format(ridge01.score(X_train, y_train)))
print("테스트 세트 점수 : {:.2f}".format(ridge01.score(X_test, y_test)))
# Out:
# 훈련 세트 점수 : 1.00
# 테스트 세트 점수 : 1.00
# 훈련 세트 점수 : 1.00
# 테스트 세트 점수 : 1.00

# %%
predlr = lr.predict(testX)
predRidge = ridge01.predict(testX)

# %% [markdown]
# ### 데이터 불러오기

# %%
sub = pd.read_csv("Auction_submission.csv")
sub['Hammer_price']=predlr
sub.to_csv('lr.csv', index=False)

# %%
sub = pd.read_csv("Auction_submission.csv")
sub['Hammer_price']=predRidge
sub.to_csv('Ridge.csv', index=False)
