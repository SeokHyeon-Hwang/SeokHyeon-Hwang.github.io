# %%
import requests as rq
url = "https://github.com/SeokHyeon-Hwang/R_data_analysis"
res=rq.get(url)
res_st = res.status_code
print(res)
# Out:
# <Response [200]>

# %%
url = "https://github.com/SeokHyeon-Hwang/R_data_analysisa"
rq.get(url)
# Out:
# <Response [404]>

# %%
def url_chk(a) :
  print(a)
  if a == 200:
    print('요청 성공')
  else:
    print('요청 실패')

# %%
url_chk(res_st)
# Out:
# 200
# 요청 성공

# %%
headers = res.headers
print(headers)

for header in headers:
  print(headers[header])
# Out:
# {'Server': 'GitHub.com', 'Date': 'Thu, 29 Nov 2018 00:35:48 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'Cache-Control': 'no-cache', 'Vary': 'X-PJAX', 'Set-Cookie': 'has_recent_activity=1; path=/; expires=Thu, 29 Nov 2018 01:35:48 -0000, logged_in=no; domain=.github.com; path=/; expires=Mon, 29 Nov 2038 00:35:48 -0000; secure; HttpOnly, _gh_sess=...%3D--a7a9638d53bbcd6f56d9039865616ef07c764cd5; path=/; secure; HttpOnly', 'X-Request-Id': 'b5cda7c0-b6f7-4096-8e73-941d5ebff9cb', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Expect-CT': 'max-age=2592000, report-uri="https://api.github.com/_private/browser/errors"', 'Content-Security-Policy': "default-src 'none'; base-uri 'self'; block-all-mixed-content; connect-src 'self' uploads.github.com status.github.com collector.githubapp.com api.github.com www
# ...

# %%
print(res.headers['Content-Type'])
# Out:
# text/html; charset=utf-8

# %%
url = 'https://github.com/pandas-dev/pandas'
res = rq.get(url)
cookies=res.cookies
print(cookies)
# Out:
# <RequestsCookieJar[<Cookie logged_in=no for .github.com/>, <Cookie _gh_sess=...--fb5ce54753e1a1b2e20c6878793021b93c913aca for github.com/>, <Cookie has_recent_activity=1 for github.com/>]>

# %%
print(list(cookies))
# Out:
# [Cookie(version=0, name='logged_in', value='no', port=None, port_specified=False, domain='.github.com', domain_specified=True, domain_initial_dot=True, path='/', path_specified=True, secure=True, expires=2174604606, discard=False, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='_gh_sess', value='...--fb5ce54753e1a1b2e20c6878793021b93c913aca', port=None, port_specified=False, domain='github.com', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=True, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False), Cookie(version=0, name='has_recent_activity', value='1', port=None, port_specified=False, domain='github.com', domain_specified=False, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=1543456206, discard=False, comment=None, comment_url=None, rest={}, rfc2109=False)]

# %%
url = 'https://www.w3schools.com/howto/tryit.asp?filename=tryhow_js_hover_tabs'
res = rq.get(url)
cookies=res.cookies
print(cookies)
# Out:
# <RequestsCookieJar[]>

# %%
url = "https://github.com/SeokHyeon-Hwang/R_data_analysisa"
res = rq.get(url, params={'key1':'value1', 'key2':'value2', 'key3':'value3', 'key4':'value4'})
print(res.url)
# Out:
# https://github.com/SeokHyeon-Hwang/R_data_analysisa?key1=value1&key2=value2&key3=value3&key4=value4
