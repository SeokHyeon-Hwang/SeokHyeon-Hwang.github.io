# %%
from bs4 import BeautifulSoup
import requests as req
import lxml
import html5lib

# %%
url = 'http://search.gmarket.co.kr/search.aspx?selecturl=total&sheaderkey=&gdlc=&SearchClassFormWord=goodsSearch&keywordOrg=%BF%A9%BC%BA%C0%C7%B7%F9&keywordCVT=%BF%A9%BC%BA%C0%C7%B7%F9%2C%BA%F2%BB%E7%C0%CC%C1%EE%BF%A9%BC%BA%C0%C7%B7%F9%2C%C1%DF%B3%E2%BF%A9%BC%BA%C0%C7%B7%F9&keywordCVTi=1&keyword=%BF%A9%BC%BA%C0%C7%B7%F9'
res = req.get(url)
#req.add_header('User-Agent', 'Mozilla/5.0')
html = res.content
soup = BeautifulSoup(html, 'html5lib')
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <html lang="ko-KR">
#  <head>
#   <title>
#    G마켓-여성의류 검색결과
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="date=no" name="format-detection"/>
#   <meta content="address=no" name="format-detection"/>
#   <meta content="email=no" name="format-detection"/>
#   <meta content="인터넷쇼핑, 오픈마켓, 패션/뷰티, 디지털, 식품/유아, 스포츠/자동차, 생활용품 , 도서/DVD, 여행/항공권, e쿠폰/티켓, 만화/게임, 공동구매, 경매, 중고, 글로벌쇼핑, 브랜드샵, 베스트셀러, 방문쇼핑몰, G스탬프, 할인쿠폰, 동영상, 이벤트 등 G마켓" name="description"/>
#   <meta content="경매,할인쿠폰,베스트셀러,공동구매,컴퓨터/핸드폰,에어컨/TV/디카,MP3/게임,패션/명품/브랜드,여성의류/속옷,남성의류/정장/빅사이즈,분유/기저귀/식품/생리대/임부복,유아동/장난감,쌀/과일/한우/생선,건강식품/음료,화장품/자동차,스포츠/다이어트,골프/등산/스키/낚시,운동화,네비게이션,리빙/침구/인테리어,애완/성인/공구,꽃배달,도서/여행/항공권,만화" name="keywords"/>
# ...

# %%
soup_item = soup.find('div', {'id' :'container'})
print(soup_item.prettify())
# Out:
# <div id="container">
#  <div class="wrap">
#   <!-- PromotionKeywordControl  Bc9655제거-->
#   <!--// PromotionKeywordControl -->
#   <!-- 변환검색어출력 -->
#   <!--// 변환검색어출력 -->
#   <!-- SRPServiceDirectControl Bc9655제거-->
#   <!--// SRPServiceDirectControl -->
#   <!--// SrpBannerControl Bc9655추가-->
#   <!--// SrpBannerControl -->
#   <!-- CommonSmartBoxControl -->
#   <div id="divSmartBoxAjaxContainer">
#    <div class="search-result-txt">
#     <h2 class="search-txt">
#      <strong>
#       `여성의류`
#      </strong>
#      <em>
#       검색 결과
#      </em>
#      <span>
#       (총
#       <strong>
#        61,342
#       </strong>
#       개)
#      </span>
#     </h2>
#     <div class="related-txt">
#      <span>
#       추천검색어
#      </span>
#      <ul>
#       <li>
#        <a href="javascript:ShoppingKeywordSearch('원피스');GoSNAChannelNoUrl('CSP0Q002');pdsClickLog('200000597', 'Utility', {'recmd_Keyword': '원피스'});">
#         원피스
#        </a>
#       </li>
#       <li>
# ...

# %%
soup_it2 = soup_item.select('div.wrap' )[0].find('div', {'id':'divAjaxContainer'}).find('div', {'id':'divListAjaxContainer'})
print(soup_it2)
# Out:
# <div id="divListAjaxContainer">
#
# <div id="itemListPosition"></div>
# <ul class="item_list type_thumb" id="searchListItems">
#
# 	<li class="plusitem firstitem">
# 		<div class="item_type" id="plusItems"><h3 class="item_title">플러스 상품</h3><span class="noti_ad"><a href="javascript:;" onclick="javascript:noti_ad('plusItems'); return false;"><em class="tag_ad" title="해당 영역은 광고상품입니다.">광고</em></a><span class="noti_ad_layer"><span class="arrow"></span><strong>플러스 상품이란?</strong> 플러스 상품 광고를 구매한 상품으로 입찰가 순으로 전시됩니다.<a class="button_close" href="javascript:;" onclick="javascript:noti_ad('plusItems'); return false;">닫기</a></span></span></div>
# 		<div class="item_info">
#
# ...

# %%
soup_it3 = soup_it2.find('ul', {'id':'searchListItems'})
print(soup_it3)
# Out:
# <ul class="item_list type_thumb" id="searchListItems">
#
# 	<li class="plusitem firstitem">
# 		<div class="item_type" id="plusItems"><h3 class="item_title">플러스 상품</h3><span class="noti_ad"><a href="javascript:;" onclick="javascript:noti_ad('plusItems'); return false;"><em class="tag_ad" title="해당 영역은 광고상품입니다.">광고</em></a><span class="noti_ad_layer"><span class="arrow"></span><strong>플러스 상품이란?</strong> 플러스 상품 광고를 구매한 상품으로 입찰가 순으로 전시됩니다.<a class="button_close" href="javascript:;" onclick="javascript:noti_ad('plusItems'); return false;">닫기</a></span></span></div>
# 		<div class="item_info">
#
# ...

# %%
soup_it4 = soup_it3.find_all('li')
print(soup_it4)
# Out:
# [<li class="plusitem firstitem">
# 		<div class="item_type" id="plusItems"><h3 class="item_title">플러스 상품</h3><span class="noti_ad"><a href="javascript:;" onclick="javascript:noti_ad('plusItems'); return false;"><em class="tag_ad" title="해당 영역은 광고상품입니다.">광고</em></a><span class="noti_ad_layer"><span class="arrow"></span><strong>플러스 상품이란?</strong> 플러스 상품 광고를 구매한 상품으로 입찰가 순으로 전시됩니다.<a class="button_close" href="javascript:;" onclick="javascript:noti_ad('plusItems'); return false;">닫기</a></span></span></div>
# 		<div class="item_info">
#
# ...

# %%
soup_it4 = soup_it3.find_all('li')
for i in soup_it4:
    title = i.find('span', {'class':'title'})
    price = i.find('span', {'class':'price'}).find('strong')
    print(title.text)
    print(price.text)
# Out:
#  5키로 감량 원피스 44~88 빅사이즈/여성의류/블라우스
# 19,800
# [SISLEY] 폭스 퍼 구스패딩(SAPD82861)
# 334,660
# [뉴발란스] NBMD626662-BK 여성 경량 트레이닝 자켓/ 뉴발란스(의...
# 67,560
#  1겨울원피스/니트투피스미니롱트위드하객룩
# 29,500
#  +겨울신상 후드티+빅사이즈/맨투맨/박스/롱/기모/오버
# 26,900
#  +겨울신상 레이어드티+ 빅사이즈/무지/기모/이너/기본
# 16,900
#  카인드 롱 코트 40469 빅사이즈 여성의류/ 공구우먼
# 84,050
#   공구우먼  밍크 파자마 원피스 40751 빅사이즈 여성의...
# 22,970
# [미센스]  미센스  Y 여성 와이드리본반넥 티셔츠-M5ZTSM262Z/ ...
# 43,000
# [미센스]  미센스  Y 여성 아크네 팬츠-M5ZSLM355Z/ 미센스(여성...
# 43,000
#  후드롱슬림원피스/밍크퍼/여성의류/기모/겨울치마
# 25,900
#  여성 반바지 빅사이즈 여성의류 반팔티 티셔츠 반팔
# 18,900
#  밍크퍼후드티/박시핏/여성의류/여자티셔츠/빅사이즈
# 25,900
#  여성 트레이닝복 반팔티 반바지 빅사이즈 여성의류 티
# 18,900
#  여성 데님자켓 청자켓 빅사이즈 여성의류 자켓 점퍼
# 26,900
#  봄 원피스 롱원피스 쉬폰 레이스 여성 의류 블라우스
# 19,900
#  (아띠벗) 특가세일/M~2XL/티셔츠/빅사이즈여성의류
# 13,900
#  엄마옷로즈맘 기모티 패딩바지 50대60대중년여성의류
# 9,900
#  겨울 원피스 모음 기모 롱 니트 빅사이즈여성의류
# 16,800
#  빅사이즈여성의류 원피스티셔츠블라우스 니트후드겨울
# 14,900
#  티셔츠 가디건 니트 셔츠 블라우스 빅사이즈여성의류
# 25,500
#  ~5XL/기모바지/겨울/빅사이즈여성의류/엄마옷/밴딩
# 17,800
#  겨울 바지 모음 슬랙스 청바지 밴딩 빅사이즈여성의류
# 26,200
# ...

# %%
soup_it4 = soup_it3.find_all('li')
i=1
for i,e in enumerate(len(soup_it4),soup_it4):
    title = e.find('span', {'class':'title'})
    price = e.find('span', {'class':'price'}).find('strong')
    print(i)
    print(title.text)
    print(price.text)
