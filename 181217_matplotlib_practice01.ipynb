# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = range(0, 100)
y = range(0, 200, 2)

# %%
plt.plot(x, y, 'ro')   # 빨간색, 'ro'
plt.show()

# %% [markdown]
# ### 여러개의 그래프 그리기

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1) # 2행 1열 의 것중에 첫번째
ax2 = fig.add_subplot(2,1,2) # 2행 1열 의 것중에 두번째
plt.show()

# %%
fig = plt.figure(figsize=(10,3))
ax1 = fig.add_subplot(1,3,1) # 1행 3열 의 것중에 첫번째
ax2 = fig.add_subplot(1,3,2) # 1행 3열 의 것중에 두번째
ax3 = fig.add_subplot(1,3,3) # 1행 3열 의 것중에 두번째
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

x=np.arrange
sin
cos

ax1.
ax2.

ax1.

# %%
x= np.arrange(10)
plt.plot(x, 1*x, label = 'y =%ix' %1)

#plt.legend()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-34062ebefebc> in <module>()
# ----> 1 x= np.arrange(10)
#       2 plt.plot(x, 1*x, label = 'y =%ix' %1)
#       3
#       4 #plt.legend()
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
# !ls -ltr
# Out:
# total 156
# drwxr-xr-x 1 root root  4096 Dec 10 17:34 sample_data
# -rw-r--r-- 1 root root 28629 Dec 17 00:20 test.csv
# -rw-r--r-- 1 root root 61194 Dec 17 00:20 train.csv
# -rw-r--r-- 1 root root 63604 Dec 17 00:20 train_modified.csv

# %%
# !mv test.csv titanic_test.csv
# !mv train.csv titanic_train.csv
# !mv train_modified.csv titanic_train_modified.csv

# %%
# !ls -ltr
# Out:
# total 156
# drwxr-xr-x 1 root root  4096 Dec 10 17:34 sample_data
# -rw-r--r-- 1 root root 28629 Dec 17 00:20 titanic_test.csv
# -rw-r--r-- 1 root root 61194 Dec 17 00:20 titanic_train.csv
# -rw-r--r-- 1 root root 63604 Dec 17 00:20 titanic_train_modified.csv

# %%
# !mv test.csv bike_test.csv
# !mv train.csv bike_train.csv
# !mv sampleSubmission.csv bike_sampleSubmission.csv

# %%
# !ls -ltr
# Out:
# total 1252
# drwxr-xr-x 1 root root   4096 Dec 10 17:34 sample_data
# -rw-r--r-- 1 root root  28629 Dec 17 00:20 titanic_test.csv
# -rw-r--r-- 1 root root  61194 Dec 17 00:20 titanic_train.csv
# -rw-r--r-- 1 root root  63604 Dec 17 00:20 titanic_train_modified.csv
# -rw-r--r-- 1 root root 142861 Dec 17 00:24 bike_sampleSubmission.csv
# -rw-r--r-- 1 root root 323856 Dec 17 00:24 bike_test.csv
# -rw-r--r-- 1 root root 648353 Dec 17 00:24 bike_train.csv

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

# %%
plt.title('제목부분')
plt.plot([1,4,9,16],
        c='b', lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')

# %%
# 쥬피터에서는 되고 콜라보에서는 안됨.

import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager, rc
import numpy as np

# 폰트 위치 지정
font_loc = "C:/Windows/Fonts/malgunbd.ttf"
font_name = font_manager.FontProperties(fname=font_loc).get_name()
matplotlib.rc('font', family=font_name)

plt.plot([1,2,3,4])
plt.xlabel('x축 한글표시')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-625f00fd3d35> in <module>()
#       7 # 폰트 위치 지정
#       8 font_loc = "C:/Windows/Fonts/malgunbd.ttf"
# ----> 9 font_name = font_manager.FontProperties(fname=font_loc).get_name()
#      10 matplotlib.rc('font', family=font_name)
#      11
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/font_manager.py in get_name(self)
#     735         properties.
#     736         """
# --> 737         return get_font(findfont(self)).family_name
#     738
#     739     def get_style(self):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Windows/Fonts/malgunbd.ttf'

# %%
import pandas as pd

# %%
test = pd.read_csv('bike_test.csv', parse_dates=['datetime'])
train = pd.read_csv('bike_train.csv', parse_dates=['datetime'])
print(test.shape, train.shape)
# Out:
# (6493, 9) (10886, 12)

# %%
new_tr = train
new_te = test

# %%
new_tr['year'] = new_tr['datetime'].dt.year
new_tr['month']=new_tr['datetime'].dt.month
new_tr['day'] = new_tr['datetime'].dt.day
new_tr['hour'] = new_tr['datetime'].dt.hour
new_tr['minute'] = new_tr['datetime'].dt.minute
new_tr['second'] = new_tr['datetime'].dt.second
new_tr['dayofweek'] = new_tr['datetime'].dt.dayofweek

# %%
new_te['year'] = new_te['datetime'].dt.year
new_te['month']=new_te['datetime'].dt.month
new_te['day'] = new_te['datetime'].dt.day
new_te['hour'] = new_te['datetime'].dt.hour
new_te['minute'] = new_te['datetime'].dt.minute
new_te['second'] = new_te['datetime'].dt.second
new_te['dayofweek'] = new_te['datetime'].dt.dayofweek

# %%
import pandas as pd

# %%
df_test = pd.read_csv('titanic_test.csv')
df_train = pd.read_csv('titanic_train.csv')

# %%
print(df_test.shape, df_train.shape)
# Out:
# (418, 11) (891, 12)

# %%
import matplotlib
import matplotlib.pylab as pylab
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import sys

# %%
print('matplotlib: {}'.format(matplotlib.__version__))
print('seaborn: {}'.format(sns.__version__))
print('python: {}'.format(sys.version))
# Out:
# matplotlib: 2.1.2
# seaborn: 0.7.1
# python: 3.6.7 (default, Oct 22 2018, 11:32:17)
# [GCC 8.2.0]

# %%
sns.set(style='white', context='notebook', palette='deep')
pylab.rcParams['figure.figsize'] = 12,8
# warnings.filterwarnings('ignore')
mpl.style.use('ggplot')
sns.set_style('white')
# %matplotlib inline

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
g = sns.FacetGrid(df_train, hue='Survived', col='Pclass', margin_titles=True,
                 palette={1:'seagreen', 0:'gray'})
g=g.map(plt.scatter, 'Fare', 'Age')

# %%
g = sns.FacetGrid(df_train, hue='Survived', col='Pclass', margin_titles=True,
                 palette={1:'seagreen', 0:'gray'})
g=g.map(plt.scatter, 'Fare', 'Age', edgecolor='w').add_legend()

# %%
grid = sns.FacetGrid(df_train, hue='Survived', col='Pclass', size=2.2, aspect=1.6)
grid.map(plt.hist, 'Age', alpha=0.5, bins=20)

# %%
grid = sns.FacetGrid(df_train, row='Embarked', size=2.2, aspect=1.6)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', paleet='deep')
grid.add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
grid = sns.FacetGrid(df_train, col='Embarked', size=2.2, aspect=1.6)
grid.map(sns.pointplot, 'Pclass', 'Survived', 'Sex', paleet='deep')
grid.add_legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
# Box plot
ax= sns.boxplot(x='Pclass', y='Age', data=df_train)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
# Box plot
ax= sns.boxplot(x='Pclass', y='Age', data=df_train)
ax= sns.stripplot(x='Pclass', y='Age', data=df_train, jitter=True)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.factorplot(y='Age', x='Sex', data=df_train, kind='box')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
sns.factorplot(y='Age', x='Sex', data=df_train, kind='box')
sns.factorplot(y='Age', x='Sex', data=df_train, hue='Pclass', kind='box')
sns.factorplot(y='Age', x='Parch', data=df_train, kind='box')
sns.factorplot(y='Age', x='SibSp', data=df_train, kind='box')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:482: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data[hue_mask])

# %%
print(type(df_train))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_train.hist(figsize=(15,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0bc27b2208>,
# ...
#       dtype=object)

# %%
df_train['Age'].hist()

# %%
df_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 17      NaN
# 18     31.0
# 19      NaN
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 26      NaN
# 27     19.0
# 28      NaN
# 29      NaN
#        ...
# 861    21.0
# 862    48.0
# 863     NaN
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 868     NaN
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 878     NaN
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
f, ax = plt.subplots(1,2, figsize=(20,10))

# %%
df_train[df_train['Survived']==0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 16            17         0       3
# 18            19         0       3
# 20            21         0       2
# 24            25         0       3
# 26            27         0       3
# 27            28         0       1
# 29            30         0       3
# 30            31         0       1
# 33            34         0       2
# 34            35         0       1
# 35            36         0       1
# 37            38         0       3
# 38            39         0       3
# 40            41         0       3
# 41            42         0       2
# 42            43         0       3
# 45            46         0       3
# ...

# %%
df_train[df_train['Survived']==0].Age
# Out:
# 0      22.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 12     20.0
# 13     39.0
# 14     14.0
# 16      2.0
# 18     31.0
# 20     35.0
# 24      8.0
# 26      NaN
# 27     19.0
# 29      NaN
# 30     40.0
# 33     66.0
# 34     28.0
# 35     42.0
# 37     21.0
# 38     18.0
# 40     40.0
# 41     27.0
# 42      NaN
# 45      NaN
# 46      NaN
# 48      NaN
# 49     18.0
# 50      7.0
# 51     21.0
#        ...
# 844    17.0
# 845    42.0
# 846     NaN
# 847    35.0
# 848    28.0
# 850     4.0
# 851    74.0
# 852     9.0
# 854    44.0
# 859     NaN
# 860    41.0
# 861    21.0
# 863     NaN
# 864    24.0
# 867    31.0
# 868     NaN
# 870    26.0
# 872    33.0
# 873    47.0
# 876    20.0
# 877    19.0
# 878     NaN
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 888     NaN
# 890    32.0
# Name: Age, Length: 549, dtype: float64

# %%
df_train[df_train['Survived']==0].Age.plot.hist()

# %%
df_train[df_train['Survived']==0].Age.describe()
# Out:
# count    424.000000
# mean      30.626179
# std       14.172110
# min        1.000000
# 25%       21.000000
# 50%       28.000000
# 75%       39.000000
# max       74.000000
# Name: Age, dtype: float64

# %%
f, ax = plt.subplots(1,2, figsize=(10,5))
df_train[df_train['Survived']==0].Age.plot.hist(ax=ax[0], bins=20,
                                               edgecolor='black',
                                               color='red')

df_train[df_train['Survived']==1].Age.plot.hist(ax=ax[1], bins=20,
                                               edgecolor='black',
                                               color='blue')

ax[0].set_title('Survived=0')
ax[1].set_title('Survived=1')

x1 = list(range(0,85, 5))
ax[0].set_xticks(x1)

x1 = list(range(0,85, 5))
ax[1].set_xticks(x1)

# %%
f, ax = plt.subplots(2,1, figsize=(10,5))
df_train[df_train['Survived']==0].Age.plot.hist(ax=ax[0], bins=20,
                                               edgecolor='black',
                                               color='red')

df_train[df_train['Survived']==1].Age.plot.hist(ax=ax[1], bins=20,
                                               edgecolor='black',
                                               color='blue')

ax[0].set_title('Survived=0')
ax[1].set_title('Survived=1')

x1 = list(range(0,85, 5))
ax[0].set_xticks(x1)

x1 = list(range(0,85, 5))
ax[1].set_xticks(x1)

# %%
import warnings

# %%
df_train['Survived'].value_counts().plot.pie()

# %%
df_train['Survived'].value_counts().plot.pie(autopct='%1.1f%%')

# %%
f, ax = plt.subplots(1, 2, figsize=(15,10))

df_train['Survived'].value_counts().plot.pie(autopct='%1.1f%%',
                                             shadow=True, 
                                            ax=ax[0])
ax[0].set_title('Survived')
ax[0].set_ylabel('')

sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Survived')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
# !apt-get install fonts-nanum*
# !apt-get install fontconfig
# !fc-cache -fv
# !cp /usr/share/fonts/truetype/nanum/Nanum* /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf/
# !rm -rf /content/.cache/matplotlib/*
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'fonts-nanum-eco' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-gothic-light' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-coding' for glob 'fonts-nanum*'
# Note, selecting 'fonts-nanum-extra' for glob 'fonts-nanum*'
# The following NEW packages will be installed:
#   fonts-nanum fonts-nanum-coding fonts-nanum-eco fonts-nanum-extra
# 0 upgraded, 4 newly installed, 0 to remove and 8 not upgraded.
# Need to get 37.0 MB of archives.
# After this operation, 145 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum-eco all 1.000-6 [14.0 MB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum-extra all 20170925-1 [12.2 MB]
# ...

# %%
import matplotlib.font_manager as fm  # 폰트 관련 용도
path = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'
fontprop = fm.FontProperties(fname=path, size=18)

plt.title("복수의 plot 명령을 한 그림에서 표현",fontproperties=fontprop)
plt.plot([1, 4, 9, 16],
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
# plt.hold(True)   # <- 1,5 버전에서는 이 코드가 필요하다.
plt.plot([9, 16, 4, 1],
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c")
# plt.hold(False)  # <- 1,5 버전에서는 이 코드가 필요하다.
plt.show()

# %%
# !pip install matplotlib --upgrade
# Out:
# ...
#     100% |████████████████████████████████| 12.9MB 2.6MB/s
# ...
#     100% |████████████████████████████████| 952kB 18.1MB/s
# ...
# yellowbrick 0.9 has requirement matplotlib<3.0,>=1.5.1, but you'll have matplotlib 3.0.2 which is incompatible.
# ...
#   Found existing installation: matplotlib 2.1.2
#     Uninstalling matplotlib-2.1.2:
#       Successfully uninstalled matplotlib-2.1.2
# ...

# %%
! pip install seaborn --upgrade
# Out:
# ...
#     100% |████████████████████████████████| 215kB 6.7MB/s
# ...
#   Found existing installation: seaborn 0.7.1
#     Uninstalling seaborn-0.7.1:
#       Successfully uninstalled seaborn-0.7.1
# ...

# %%
f, ax = plt.subplots(1,2, figsize=(18,8))
type(ax)
# Out:
# numpy.ndarray

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train[['Sex', 'Survived']]
# Out:
#         Sex  Survived
# 0      male         0
# 1    female         1
# 2    female         1
# 3    female         1
# 4      male         0
# 5      male         0
# 6      male         0
# 7      male         0
# 8    female         1
# 9    female         1
# 10   female         1
# 11   female         1
# 12     male         0
# 13     male         0
# 14   female         0
# 15   female         1
# 16     male         0
# 17     male         1
# 18   female         0
# 19   female         1
# 20     male         0
# 21     male         1
# 22   female         1
# 23     male         1
# 24   female         0
# 25   female         1
# 26     male         0
# 27     male         0
# 28   female         1
# 29     male         0
# ..      ...       ...
# 861    male         0
# 862  female         1
# 863  female         0
# 864    male         0
# 865  female         1
# 866  female         1
# 867    male         0
# 868    male         0
# 869    male         1
# ...

# %%
df_train[['Sex', 'Survived']].groupby(['Sex']).count()
print( df_train[ ['Sex', 'Survived'] ].groupby(['Sex']).mean() )
print( df_train[ ['Sex', 'Survived'] ].groupby(['Sex']).max() )
print( df_train[ ['Sex', 'Survived'] ].groupby(['Sex']).min() )
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908
#         Survived
# Sex
# female         1
# male           1
#         Survived
# Sex
# female         0
# male           0

# %%
f, ax = plt.subplots(1,2, figsize=(15,8))


## 첫번째 그래프
df_train[ ['Sex', 'Survived'] ].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')


## 두번째 그래프
sns.countplot('Sex', hue="Survived", data=df_train, ax=ax[1])
ax[1].set_title('Sex vs Survived')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1468: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data[hue_mask])

# %%
## 2-4 Mutivariate Plots

# %%
pd.plotting.scatter_matrix(df_train, figsize=(10,10))
plt.figure()

# %%
sns.violinplot(data=df_train, x='Sex', y='Age')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)

# %%
f, ax = plt.subplots(2,2, figsize=(8,4))

sns.violinplot(data=df_train, x='Sex', y='Age')

sns.violinplot(data=df_train, x='Sex', y='Age')

## 첫번째 그래프
df_train[ ['Sex', 'Survived'] ].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')


## 두번째 그래프
sns.countplot('Sex', hue="Survived", data=df_train, ax=ax[1])
ax[1].set_title('Sex vs Survived')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:588: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:816: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-f848e7e3da6f> in <module>()
#       6
#       7 ## 첫번째 그래프
# ----> 8 df_train[ ['Sex', 'Survived'] ].groupby(['Sex']).mean().plot.bar(ax=ax[0])
#       9 ax[0].set_title('Survived vs Sex')
#      10
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in bar(self, x, y, **kwds)
#    2714         axes : matplotlib.AxesSubplot or np.array of them
#    2715         """
# -> 2716         return self(kind='bar', x=x, y=y, **kwds)
# ...

# %%
a=sns.FacetGrid(df_train, hue='Survived', aspect=2)
a.map(sns.kdeplot, 'Age', shade=True)
a.set(xlim=(0, df_train['Age'].max()+10))
a.add_legend()

# %%
sns.jointplot(x='Fare', y='Age', data=df_train)

# %%
sns.jointplot(x='Fare', y='Age', data=df_train, kind='reg')

# %%
sns.jointplot(x='Fare', y='Age',hue='Survived' , data=df_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-92277118bbdf> in <module>()
# ----> 1 sns.jointplot(x='Fare', y='Age',hue='Survived' , data=df_train)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1725             not_na = pd.notnull(x_array) & pd.notnull(y_array)
#    1726             x_array = x_array[not_na]
# -> 1727             y_array = y_array[not_na]
#    1728
#    1729         self.x = x_array
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#
# ...

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train[['Survived', 'SibSp', 'Parch', 'Age', 'Fare']].corr()
# Out:
#           Survived     SibSp     Parch       Age      Fare
# Survived  1.000000 -0.035322  0.081629 -0.077221  0.257307
# SibSp    -0.035322  1.000000  0.414838 -0.308247  0.159651
# Parch     0.081629  0.414838  1.000000 -0.189119  0.216225
# Age      -0.077221 -0.308247 -0.189119  1.000000  0.096067
# Fare      0.257307  0.159651  0.216225  0.096067  1.000000

# %%
g = sns.heatmap(df_train[['Survived', 'SibSp', 'Parch', 'Age', 'Fare']].corr())

# %%
g = sns.heatmap(df_train[['Survived', 'SibSp', 'Parch', 'Age', 'Fare']].corr(),
               annot=True, fmt='.2f', cmap='cubehelix_r')
