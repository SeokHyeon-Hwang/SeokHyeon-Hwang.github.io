# %%
import numpy as np
import matplotlib.pyplot as plt
import mglearn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
# %matplotlib inline

# %%
#!pip install mglearn
def make_wave(n_samples=100):
  rnd = np.random.RandomState(42)
  x = rnd.uniform(-30, 30, size=n_samples)
  y_no_noise = (np.sin(4 * x) + x)
  y = (y_no_noise + rnd.normal(size=len(x))) / 2
  return x.reshape(-1, 1), y

# %%
X, y = make_wave(n_samples=10)
print(X.shape, y.shape)
print(X.dtype, y.dtype)
print(X.size, y.size)
print(X.ndim, y.ndim)
# Out:
# (10, 1) (10,)
# float64 float64
# 10 10
# 2 1

# %%
mglearn.plots.plot_linear_regression_wave()
# Out:
# w[0]: 0.393906  b: -0.031804

# %%
X, y = make_wave(n_samples=60)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
lr = LinearRegression().fit(X_train, y_train)

# %%
print("lr.coef_ : {}".format(lr.coef_))
print("lr.intercept_ : {}".format(lr.intercept_))
# Out:
# lr.coef_ : [0.49466614]
# lr.intercept_ : -0.10033095048199736

# %%
print("훈련 데이터 세트 점수 : {:.2f}".format(lr.score(X_train, y_train)))
print("테스트 데이터 세트 점수 : {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# 훈련 데이터 세트 점수 : 1.00
# 테스트 데이터 세트 점수 : 1.00

# %%
ax= sns.boxplot(x="Pclass", y="Age", data=df_train)
ax= sns.stripplot(x="Pclass", y="Age", data=df_train, jitter=True, edgecolor="gray")
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:454: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   box_data = remove_na(group_data)

# %%
df_train.hist(figsize=(10,10))
plt.figure()

# %%
df_train['Age'].hist()

# %%
f,ax=plt.subplots(1,2,figsize=(15,10))
df_train[df_train['Survived']==0].Age.plot.hist(ax=ax[0],bins=20,edgecolor='black',color='red')
ax[0].set_title('Survived= 0')
x1=list(range(0,85,5))   
ax[0].set_xticks(x1)     # 첫번째그래프 x축눈금

df_train[df_train['Survived']==1].Age.plot.hist(ax=ax[1],
                                 bins=20,edgecolor='black', color='green')
ax[1].set_title('Survived= 1')
x2=list(range(0,85,5))
ax[1].set_xticks(x2)
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(13,8))
df_train['Survived'].value_counts().plot.pie(explode=[0,0.1],
                      autopct='%1.1f%%',ax=ax[0],shadow=True)  


ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=df_train,ax=ax[1])
ax[1].set_title('Survived')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/categorical.py:1428: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   stat_data = remove_na(group_data)

# %%
plt.figure(figsize=(7,4))
sns.heatmap(df_train.corr(), annot=True, cmap='cubehelix_r'  )
plt.show()

# %%
df_train['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df_train['Pclass'].value_counts().plot(kind='bar')

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.linear_model import Ridge   # 릿지회귀
import matplotlib.pyplot as plt

# 한글
#import matplotlib
#from matplotlib import font_manager, rc
#font_loc = "C:/Windows/Fonts/malgunbd.ttf"
#font_name = font_manager.FontProperties(fname=font_loc).get_name()
#matplotlib.rc('font', family=font_name)

# %matplotlib inline

# %%
def load_extended_boston():
    boston = load_boston()  # 데이터 셋 불러오기
    X = boston.data         # 입력 데이터 
    
    X = MinMaxScaler().fit_transform(boston.data)  # 입력 데이터 정규화
    X = PolynomialFeatures(degree=2, include_bias=False).fit_transform(X)
    return X, boston.target

# %%
X, y = load_extended_boston()
print(X.shape, y.shape)
# Out:
# (506, 104) (506,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
lr = LinearRegression().fit(X_train, y_train)

print("훈련 데이터 세트 점수 : {:.2f}".format(lr.score(X_train, y_train)))
print("테스트 데이터 세트 점수 : {:.2f}".format(lr.score(X_test, y_test)))
# Out:
# 훈련 데이터 세트 점수 : 0.94
# 테스트 데이터 세트 점수 : 0.78

# %%
ls -ltr
# Out:
# total 2072
# drwxr-xr-x 1 root root   4096 Dec 18 20:29 sample_data/
# -rw-r--r-- 1 root root 142861 Dec 24 00:45 sampleSubmission.csv
# -rw-r--r-- 1 root root 323856 Dec 24 00:45 biketest.csv
# -rw-r--r-- 1 root root 622072 Dec 24 00:45 biketrain.csv
# -rw-r--r-- 1 root root  28629 Dec 24 00:48 titanictest.csv
# -rw-r--r-- 1 root root  61194 Dec 24 00:48 titanictrain.csv
# drwxr-xr-x 3 root root   4096 Dec 24 01:10 cache/
# -rw-r--r-- 1 root root 272439 Dec 24 02:43 Auction_master_test_ansi.csv
# -rw-r--r-- 1 root root 653254 Dec 24 02:43 Auction_master_train_ansi.csv

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from sklearn.linear_model import Ridge   # 릿지회귀
import matplotlib.pyplot as plt
import pandas as pd

# %%
def load_extended_boston():
    boston = load_boston()  # 데이터 셋 불러오기
    X = boston.data         # 입력 데이터 
    
    X = MinMaxScaler().fit_transform(boston.data)  # 입력 데이터 정규화
    X = PolynomialFeatures(degree=2, include_bias=False).fit_transform(X)
    return X, boston.target

# %%
df_tr=pd.read_csv('dacon3_tr_del_col.csv')
df_te=pd.read_csv('dacon3_te_del_col.csv')

# %%
print(X.shape)
# Out:
# (1919, 77)

# %%
print(df_tr.shape)
# Out:
# (1919, 11)

# %%
#y= df_tr['Hammer_price']

# %%
y= df_tr.drop('Hammer_price', 1)

# %%
print(df_tr.shape, y.shape)
# Out:
# (1919, 11) (1919, 10)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_tr.drop('Hammer_price', axis=1), df_tr['Hammer_price'], random_state=42)

# %%
# from sklearn.linear_model import Ridge
ridge = Ridge().fit(X_train, y_train)
print("훈련 세트 점수 : {:.2f}".format(ridge.score(X_train, y_train)))
print("테스트 세트 점수 : {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# 훈련 세트 점수 : 0.99
# 테스트 세트 점수 : 0.96
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.795622e-19
#   overwrite_a=True).T

# %%
# from sklearn.linear_model import Ridge
ridge = Ridge(0.3).fit(X_train, y_train)
print("훈련 세트 점수 : {:.2f}".format(ridge.score(X_train, y_train)))
print("테스트 세트 점수 : {:.2f}".format(ridge.score(X_test, y_test)))
# Out:
# 훈련 세트 점수 : 0.99
# 테스트 세트 점수 : 0.96
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number2.793318e-19
#   overwrite_a=True).T

# %%
pred = ridge.predict(df_te.drop('Hammer_price', axis=1))  # 예측
pred
# Out:
# array([1.36100112e+08, 1.48575563e+08, 1.36449081e+08, 1.35623301e+08,
#        1.33970678e+08, 1.33144898e+08, 1.42792978e+08, 2.00550893e+08,
#        1.81550335e+08, 2.94121381e+08, 1.65881710e+08, 7.39692914e+07,
#        9.98450314e+07, 7.89445254e+07, 4.36373920e+08, 7.61093910e+07,
#        4.50854421e+08, 1.34563502e+08, 1.37395763e+08, 1.76937163e+08,
#        6.88253988e+07, 5.55551708e+08, 1.65917503e+08, 1.69419381e+08,
#        1.46879333e+08, 2.96260240e+08, 1.40056468e+08, 2.97458996e+08,
#        1.65516970e+08, 2.16589906e+08, 1.01281803e+08, 9.26945576e+07,
#        3.39974686e+08, 1.17934658e+08, 1.43760475e+08, 1.86628743e+08,
#        2.24819100e+08, 1.73549893e+08, 1.83600186e+08, 4.39665164e+08,
#        8.60903504e+07, 3.63245484e+08, 3.33422712e+08, 1.68367925e+08,
#        2.74496147e+08, 1.75727077e+08, 1.24311553e+08, 5.76928035e+08,
#        1.61684746e+08, 1.11379037e+08, 3.33301728e+07, 2.03057679e+08,
# ...

# %%
print(df_tr.shape, df_te.shape)
# Out:
# (1919, 11) (829, 11)

# %%
df_tr.columns
# Out:
# Index(['Unnamed: 0', 'Claim_price', 'Auction_count', 'Total_land_gross_area',
#        'Total_land_auction_area', 'Total_building_auction_area',
#        'Total_appraisal_price', 'Minimum_sales_price', 'Total_floor',
#        'Current_floor', 'Hammer_price'],
#       dtype='object')

# %%
df_te.columns
# Out:
# Index(['Unnamed: 0', 'Claim_price', 'Auction_count', 'Total_land_gross_area',
#        'Total_land_auction_area', 'Total_building_auction_area',
#        'Total_appraisal_price', 'Minimum_sales_price', 'Total_floor',
#        'Current_floor', 'Hammer_price'],
#       dtype='object')

# %%
sub=pd.read_csv('Auction_submission.csv')
